# %%
import pandas as pd
import numpy as np
from collections import OrderedDict

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/Colab Notebooks/multi_plates_results/'

# %%
df_chuffed = pd.read_csv(path + 'multiplates_models_evaluation_complete_chuffed_config.csv')
df_cpsat = pd.read_csv(path + 'multiplates_models_evaluation_complete_cpsat_config.csv')
df_gurobi = pd.read_csv(path + 'multiplates_models_evaluation_complete_gurobi_config.csv')
df_chuffed2 = pd.read_csv(path + 'multiplates_models_evaluation_two_only_chuffed_config.csv')
df_cpsat2 = pd.read_csv(path + 'multiplates_models_evaluation_two_only_cpsat_config.csv')
df_gurobi2 = pd.read_csv(path + 'multiplates_models_evaluation_two_only_gurobi_config.csv')
df_chuffed
# Out:
#               Solver  Model                                             Name  \
# 0     chuffed_config    I_A   multiplate_dzn_files/multiplate_t2_w2_s2_0.dzn
# 1     chuffed_config    I_B   multiplate_dzn_files/multiplate_t2_w2_s2_0.dzn
# 2     chuffed_config   II_A   multiplate_dzn_files/multiplate_t2_w2_s2_0.dzn
# 3     chuffed_config   II_B   multiplate_dzn_files/multiplate_t2_w2_s2_0.dzn
# 4     chuffed_config  III_A   multiplate_dzn_files/multiplate_t2_w2_s2_0.dzn
# ...              ...    ...                                              ...
# 1886  chuffed_config   II_A  multiplate_dzn_files/multiplate_t10_w6_s5_4.dzn
# 1887  chuffed_config   II_B  multiplate_dzn_files/multiplate_t10_w6_s5_4.dzn
# 1888  chuffed_config  III_A  multiplate_dzn_files/multiplate_t10_w6_s5_4.dzn
# 1889  chuffed_config  III_B  multiplate_dzn_files/multiplate_t10_w6_s5_4.dzn
# 1890  chuffed_config    I_A  multiplate_dzn_files/multiplate_t10_w6_s5_5.dzn
#
#        NumTargetPlates   SizeTargetPlates   NumSourcePlates   NumCombinations  \
# 0                    2                  2                 2                 4
# 1                    2                  2                 2                 4
# 2                    2                  2                 2                 4
# 3                    2                  2                 2                 4
# 4                    2                  2                 2                 4
# ...                ...                ...               ...               ...
# 1886                10                  6                 5                60
# 1887                10                  6                 5                60
# 1888                10                  6                 5                60
# 1889                10                  6                 5                60
# 1890                10                  6                 5                60
#
#       SolutionTime  IsTimeout  TotalTime   NbSwaps
# 0             0.28      False       0.28         2
# 1             0.30      False       0.30         2
# 2             0.28      False       0.28         2
# 3             0.30      False       0.30         2
# 4             0.33      False       0.33         2
# ...            ...        ...        ...       ...
# 1886        300.06       True     300.00        26
# 1887        300.06       True     300.00        26
# 1888        300.12       True     300.00        26
# 1889        300.13       True     300.00        26
# 1890        300.05       True     300.00        17
#
# [1891 rows x 11 columns]

# %%
df_gurobi
# Out:
#              Solver  Model                                              Name  \
# 0     gurobi_config    I_A    multiplate_dzn_files/multiplate_t2_w2_s2_0.dzn
# 1     gurobi_config    I_B    multiplate_dzn_files/multiplate_t2_w2_s2_0.dzn
# 2     gurobi_config   II_A    multiplate_dzn_files/multiplate_t2_w2_s2_0.dzn
# 3     gurobi_config   II_B    multiplate_dzn_files/multiplate_t2_w2_s2_0.dzn
# 4     gurobi_config  III_A    multiplate_dzn_files/multiplate_t2_w2_s2_0.dzn
# ...             ...    ...                                               ...
# 2875  gurobi_config    I_B  multiplate_dzn_files/multiplate_t15_w8_s10_9.dzn
# 2876  gurobi_config   II_A  multiplate_dzn_files/multiplate_t15_w8_s10_9.dzn
# 2877  gurobi_config   II_B  multiplate_dzn_files/multiplate_t15_w8_s10_9.dzn
# 2878  gurobi_config  III_A  multiplate_dzn_files/multiplate_t15_w8_s10_9.dzn
# 2879  gurobi_config  III_B  multiplate_dzn_files/multiplate_t15_w8_s10_9.dzn
#
#        NumTargetPlates   SizeTargetPlates   NumSourcePlates   NumCombinations  \
# 0                    2                  2                 2                 4
# 1                    2                  2                 2                 4
# 2                    2                  2                 2                 4
# 3                    2                  2                 2                 4
# 4                    2                  2                 2                 4
# ...                ...                ...               ...               ...
# 2875                15                  8                10               120
# 2876                15                  8                10               120
# 2877                15                  8                10               120
# 2878                15                  8                10               120
# 2879                15                  8                10               120
#
#       SolutionTime  IsTimeout  TotalTime   NbSwaps
# 0             0.29      False       0.29         2
# 1             0.29      False       0.29         2
# 2             0.28      False       0.28         2
# 3             0.30      False       0.30         2
# 4             0.28      False       0.28         2
# ...            ...        ...        ...       ...
# 2875        300.06       True     300.00        95
# 2876        300.04       True     300.00        94
# 2877        300.06       True     300.00        95
# 2878        300.11       True     300.00        94
# 2879        300.15       True     300.00        94
#
# [2880 rows x 11 columns]

# %%
df = pd.concat([df_chuffed, df_cpsat, df_gurobi])
df2 = pd.concat([df_chuffed2, df_cpsat2, df_gurobi2])

# %%
df
# Out:
#               Solver  Model                                              Name  \
# 0     chuffed_config    I_A    multiplate_dzn_files/multiplate_t2_w2_s2_0.dzn
# 1     chuffed_config    I_B    multiplate_dzn_files/multiplate_t2_w2_s2_0.dzn
# 2     chuffed_config   II_A    multiplate_dzn_files/multiplate_t2_w2_s2_0.dzn
# 3     chuffed_config   II_B    multiplate_dzn_files/multiplate_t2_w2_s2_0.dzn
# 4     chuffed_config  III_A    multiplate_dzn_files/multiplate_t2_w2_s2_0.dzn
# ...              ...    ...                                               ...
# 2875   gurobi_config    I_B  multiplate_dzn_files/multiplate_t15_w8_s10_9.dzn
# 2876   gurobi_config   II_A  multiplate_dzn_files/multiplate_t15_w8_s10_9.dzn
# 2877   gurobi_config   II_B  multiplate_dzn_files/multiplate_t15_w8_s10_9.dzn
# 2878   gurobi_config  III_A  multiplate_dzn_files/multiplate_t15_w8_s10_9.dzn
# 2879   gurobi_config  III_B  multiplate_dzn_files/multiplate_t15_w8_s10_9.dzn
#
#        NumTargetPlates   SizeTargetPlates   NumSourcePlates   NumCombinations  \
# 0                    2                  2                 2                 4
# 1                    2                  2                 2                 4
# 2                    2                  2                 2                 4
# 3                    2                  2                 2                 4
# 4                    2                  2                 2                 4
# ...                ...                ...               ...               ...
# 2875                15                  8                10               120
# 2876                15                  8                10               120
# 2877                15                  8                10               120
# 2878                15                  8                10               120
# 2879                15                  8                10               120
#
#       SolutionTime  IsTimeout  TotalTime   NbSwaps
# 0             0.28      False       0.28         2
# 1             0.30      False       0.30         2
# 2             0.28      False       0.28         2
# 3             0.30      False       0.30         2
# 4             0.33      False       0.33         2
# ...            ...        ...        ...       ...
# 2875        300.06       True     300.00        95
# 2876        300.04       True     300.00        94
# 2877        300.06       True     300.00        95
# 2878        300.11       True     300.00        94
# 2879        300.15       True     300.00        94
#
# [7651 rows x 11 columns]

# %%
df2
# Out:
#               Solver  Model  \
# 0     chuffed_config    I_A
# 1     chuffed_config    I_B
# 2     chuffed_config   II_A
# 3     chuffed_config   II_B
# 4     chuffed_config  III_A
# ...              ...    ...
# 2875   gurobi_config    I_B
# 2876   gurobi_config   II_A
# 2877   gurobi_config   II_B
# 2878   gurobi_config  III_A
# 2879   gurobi_config  III_B
#
#                                                    Name   NumTargetPlates  \
# 0     multiplate_dzn_files_2_only/multiplate_t2_w2_s...                 2
# 1     multiplate_dzn_files_2_only/multiplate_t2_w2_s...                 2
# 2     multiplate_dzn_files_2_only/multiplate_t2_w2_s...                 2
# 3     multiplate_dzn_files_2_only/multiplate_t2_w2_s...                 2
# 4     multiplate_dzn_files_2_only/multiplate_t2_w2_s...                 2
# ...                                                 ...               ...
# 2875  multiplate_dzn_files_2_only/multiplate_t15_w8_...                15
# 2876  multiplate_dzn_files_2_only/multiplate_t15_w8_...                15
# 2877  multiplate_dzn_files_2_only/multiplate_t15_w8_...                15
# 2878  multiplate_dzn_files_2_only/multiplate_t15_w8_...                15
# 2879  multiplate_dzn_files_2_only/multiplate_t15_w8_...                15
#
#        SizeTargetPlates   NumSourcePlates   NumCombinations  SolutionTime  \
# 0                     2                 2                 4          0.78
# 1                     2                 2                 4          0.35
# 2                     2                 2                 4          0.49
# 3                     2                 2                 4          0.49
# 4                     2                 2                 4          0.47
# ...                 ...               ...               ...           ...
# 2875                  8                10               120        300.04
# 2876                  8                10               120        300.02
# 2877                  8                10               120        300.05
# 2878                  8                10               120        300.13
# 2879                  8                10               120        300.15
#
#       IsTimeout  TotalTime   NbSwaps
# 0         False       0.78         1
# 1         False       0.35         1
# 2         False       0.49         1
# 3         False       0.49         1
# 4         False       0.47         1
# ...         ...        ...       ...
# 2875       True     300.00        32
# 2876       True     300.00        31
# 2877       True     300.00        30
# 2878       True     300.00        30
# 2879       True     300.00        31
#
# [8640 rows x 11 columns]

# %%
solvers = df['Solver'].drop_duplicates().tolist()
solvers
# Out:
# ['chuffed_config', 'cpsat_config', 'gurobi_config']

# %%
models = df['Model'].drop_duplicates().tolist()
models
# Out:
# ['I_A', 'I_B', 'II_A', 'II_B', 'III_A', 'III_B']

# %%
nb_target_plates = df[' NumTargetPlates'].drop_duplicates().tolist()
size_target_plates = df[' SizeTargetPlates'].drop_duplicates().tolist()
nb_source_plates = df[' NumSourcePlates'].drop_duplicates().tolist()
nb_combinations_plates = df[' NumCombinations'].drop_duplicates().tolist()
nb_target_plates,size_target_plates,nb_source_plates,nb_combinations_plates
# Out:
# ([2, 5, 10, 15],
#  [2, 4, 6, 8],
#  [2, 5, 10],
#  [4, 8, 12, 16, 10, 20, 30, 40, 60, 80, 90, 120])

# %%
problems = df['Name'].drop_duplicates().tolist()
problems2 = df2['Name'].drop_duplicates().tolist()

# %%
problems_light = df.loc[(df[' NumTargetPlates'] == 2) | (df[' SizeTargetPlates'] == 2) | (df[' NumSourcePlates'] == 2)]['Name'].drop_duplicates().tolist()
problems_medium = df.loc[((df[' NumTargetPlates'] == 5) | (df[' NumTargetPlates'] == 10)) & ((df[' SizeTargetPlates'] > 2) | (df[' SizeTargetPlates'] == 6)) & (df[' NumSourcePlates'] == 5)]['Name'].drop_duplicates().tolist()
problems_hard = df.loc[((df[' NumTargetPlates'] == 15) | (df[' NumSourcePlates'] == 10)) & ((df[' NumTargetPlates'] > 2) & (df[' SizeTargetPlates'] > 2) & (df[' NumSourcePlates'] > 2))]['Name'].drop_duplicates().tolist()
len(problems), len(problems_light), len(problems_medium), len(problems_hard)
# Out:
# (480, 300, 60, 120)

# %%
problems2_light = df2.loc[(df2[' NumTargetPlates'] == 2) | (df2[' SizeTargetPlates'] == 2) | (df2[' NumSourcePlates'] == 2)]['Name'].drop_duplicates().tolist()
problems2_medium = df2.loc[((df2[' NumTargetPlates'] == 5) | (df2[' NumTargetPlates'] == 10)) & ((df2[' SizeTargetPlates'] > 2) | (df2[' SizeTargetPlates'] == 6)) & (df2[' NumSourcePlates'] == 5)]['Name'].drop_duplicates().tolist()
problems2_hard = df2.loc[((df2[' NumTargetPlates'] == 15) | (df2[' NumSourcePlates'] == 10)) & ((df2[' NumTargetPlates'] > 2) & (df2[' SizeTargetPlates'] > 2) & (df2[' NumSourcePlates'] > 2))]['Name'].drop_duplicates().tolist()
len(problems2), len(problems2_light), len(problems2_medium), len(problems2_hard)
# Out:
# (480, 300, 60, 120)

# %%
list(set(problems_light) & set(problems_medium)), list(set(problems_light) & set(problems_hard)), list(set(problems_hard) & set(problems_medium))
# Out:
# ([], [], [])

# %%
list(set(problems2_light) & set(problems2_medium)), list(set(problems2_light) & set(problems2_hard)), list(set(problems2_hard) & set(problems2_medium))
# Out:
# ([], [], [])

# %%
# verification - make sure that each model under each solver produces the same optimal solution
for problem in problems:
  problem_solutions_swaps = df.loc[(df['Name'] == problem) & (df['IsTimeout'] == False)][' NbSwaps'].tolist()
  if problem_solutions_swaps == []:
    None
  elif min(problem_solutions_swaps) == max(problem_solutions_swaps):
    None
  else:
    print(problem + ': ' + str(problem_solutions_swaps))

# %%
def print_general_stats(df_passed, models_passed, problems_passed):
  print('NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total')

  nb_problems = len(problems_passed)

  best_result_per_problem = {}
  solvers_passed = df_passed['Solver'].drop_duplicates().tolist()

  for solver in solvers_passed:
    for model in models_passed:
      best_result_per_problem[(solver,model)] = 0

  problem_solutions_all = df_passed.loc[df_passed['Name'].isin(problems_passed)]

  for problem in problems_passed:
    problem_solutions = df_passed.loc[(df_passed['Name'] == problem) & (df_passed[' NbSwaps'] != -1)]
    # the logic goes as follows - if the timeout is not reached it means we found the best solution
    min_time = problem_solutions['TotalTime'].min()
    min_swaps = problem_solutions[' NbSwaps'].min()
    for solver in solvers_passed:
      for model in models:
        if problem_solutions.loc[(problem_solutions['Solver'] == solver) & (problem_solutions['Model'] == model)].shape[0] == 0:
          None
        elif (min_time  == problem_solutions.loc[(problem_solutions['Solver'] == solver) & (problem_solutions['Model'] == model)]['TotalTime'].iloc[0]) & (min_swaps == problem_solutions.loc[(problem_solutions['Solver'] == solver) & (problem_solutions['Model'] == model)][' NbSwaps'].iloc[0]):
          best_result_per_problem[(solver,model)] += 1

  for solver in solvers_passed:
    for model in models_passed:
      collect_timeouts =  problem_solutions_all.loc[(problem_solutions_all['Solver'] == solver) & (problem_solutions_all['Model'] == model) & (problem_solutions_all['IsTimeout'] == True)].shape[0]
      collect_no_solutions =  problem_solutions_all.loc[(problem_solutions_all['Solver'] == solver) & (problem_solutions_all['Model'] == model) & (problem_solutions_all[' NbSwaps'] == -1)].shape[0]
      total_time_all = problem_solutions_all.loc[(problem_solutions_all['Solver'] == solver) & (problem_solutions_all['Model'] == model)]['TotalTime'].sum()
     #average_time_notos = df_passed.loc[(df_passed['Solver'] == solver) & (df_passed['Model'] == model) & (df_passed['IsTimeout'] == False)]['TotalTime'].sum()
      print(str(nb_problems) + ' & ' + '%15s' % solver + ' & ' + '%5s' % model + ' & ' + '%3s' % str(collect_timeouts) + ' & ' + '%3s' % str(collect_no_solutions) + ' & ' + '%3s' % str(best_result_per_problem[(solver,model)]) + ' & ' + '%7s' % "{:.2f}".format(total_time_all / nb_problems) + ' & ' + '%5s' % "{:.2f}".format(total_time_all / 3600))
  print('\n')

# %%
def print_general_stats_enumerate(df_passed, models_passed, nb_target_plates_passed, size_target_plates_passed, nb_source_plates_passed):
  for nb_target_plates_ex in nb_target_plates_passed:
    for size_target_plates_ex in size_target_plates_passed:
      for nb_source_plates_ex in nb_source_plates_passed:
        problems_ex = df_passed.loc[(df_passed[' NumTargetPlates'] == nb_target_plates_ex) & (df_passed[' SizeTargetPlates'] == size_target_plates_ex) & (df_passed[' NumSourcePlates'] == nb_source_plates_ex)]['Name'].drop_duplicates().tolist()
        print('nb_target_plates: ' + str(nb_target_plates_ex) + ' size_target_plates: ' + str(size_target_plates_ex) + ' nb_source_plates: ' + str(nb_source_plates_ex) + ' nb_problems: ' + str(len(problems_ex)))
        print_general_stats(df_passed, models_passed, problems_ex)
        print('\n')

# %%
def best_result_aggr(df_passed, models_passed, problems_passed):
  best_result_per_problem = {}
  solvers_passed = df_passed['Solver'].drop_duplicates().tolist()
  for solver in solvers_passed:
    for model in models_passed:
      best_result_per_problem[(solver,model)] = 0

  for problem in problems_passed:
    problem_solutions = df_passed.loc[(df_passed['Name'] == problem) & (df_passed[' NbSwaps'] != -1)]
    # the logic goes as follows - if the timeout is not reached it means we found the best solution
    min_time = problem_solutions['TotalTime'].min()
    min_swaps = problem_solutions[' NbSwaps'].min()
    for solver in solvers_passed:
      for model in models:
        if problem_solutions.loc[(problem_solutions['Solver'] == solver) & (problem_solutions['Model'] == model)].shape[0] == 0:
          None
        elif (min_time  == problem_solutions.loc[(problem_solutions['Solver'] == solver) & (problem_solutions['Model'] == model)]['TotalTime'].iloc[0]) & (min_swaps == problem_solutions.loc[(problem_solutions['Solver'] == solver) & (problem_solutions['Model'] == model)][' NbSwaps'].iloc[0]):
          best_result_per_problem[(solver,model)] += 1
  return best_result_per_problem

# %%
print_general_stats(df, models, problems)
# Out:
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 480 &  chuffed_config &   I_A &  60 &   0 &  81 &   40.57 &  5.41
# 480 &  chuffed_config &   I_B &  50 &   0 &  26 &   36.60 &  4.88
# 480 &  chuffed_config &  II_A &  58 &   0 &  81 &   38.57 &  5.14
# 480 &  chuffed_config &  II_B &  46 &   0 &  31 &   36.52 &  4.87
# 480 &  chuffed_config & III_A &  66 &   0 &  51 &   50.02 &  6.67
# 480 &  chuffed_config & III_B &  66 &   0 &  19 &   47.88 &  6.38
# 480 &    cpsat_config &   I_A & 139 & 139 &  89 &   94.67 & 12.62
# 480 &    cpsat_config &   I_B & 139 & 139 &  14 &   95.20 & 12.69
# 480 &    cpsat_config &  II_A & 140 & 140 &  44 &   94.53 & 12.60
# 480 &    cpsat_config &  II_B & 140 & 140 &   7 &   94.50 & 12.60
# 480 &    cpsat_config & III_A & 139 & 139 &  31 &   94.50 & 12.60
# 480 &    cpsat_config & III_B & 139 & 139 &   6 &   94.47 & 12.60
# 480 &   gurobi_config &   I_A & 160 &   0 & 126 &  109.84 & 14.65
# 480 &   gurobi_config &   I_B & 160 &   0 & 105 &  110.03 & 14.67
# 480 &   gurobi_config &  II_A & 159 &   0 & 122 &  109.48 & 14.60
# 480 &   gurobi_config &  II_B & 159 &   0 & 109 &  109.27 & 14.57
# 480 &   gurobi_config & III_A & 160 &   0 & 118 &  109.68 & 14.62
# 480 &   gurobi_config & III_B & 160 &   0 & 104 &  109.84 & 14.64

# %%
print_general_stats(df2, models, problems2)
# Out:
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 480 &  chuffed_config &   I_A & 100 &   0 &  91 &   67.11 &  8.95
# 480 &  chuffed_config &   I_B &  99 &   0 &  47 &   65.42 &  8.72
# 480 &  chuffed_config &  II_A & 104 &   0 &  43 &   70.33 &  9.38
# 480 &  chuffed_config &  II_B & 103 &   0 &  32 &   68.67 &  9.16
# 480 &  chuffed_config & III_A & 122 &   0 &  25 &   80.56 & 10.74
# 480 &  chuffed_config & III_B & 123 &   0 &  22 &   80.99 & 10.80
# 480 &    cpsat_config &   I_A &  89 &  89 &  89 &   60.22 &  8.03
# 480 &    cpsat_config &   I_B &  90 &  90 &  41 &   60.16 &  8.02
# 480 &    cpsat_config &  II_A &  89 &  89 &  55 &   59.66 &  7.95
# 480 &    cpsat_config &  II_B &  87 &  87 &  15 &   59.59 &  7.95
# 480 &    cpsat_config & III_A &  88 &  88 &  48 &   59.75 &  7.97
# 480 &    cpsat_config & III_B &  89 &  89 &  18 &   60.49 &  8.07
# 480 &   gurobi_config &   I_A & 123 &   0 & 111 &   86.71 & 11.56
# 480 &   gurobi_config &   I_B & 124 &   0 &  62 &   87.22 & 11.63
# 480 &   gurobi_config &  II_A & 122 &   0 &  70 &   87.33 & 11.64
# 480 &   gurobi_config &  II_B & 121 &   0 &  58 &   86.37 & 11.52
# 480 &   gurobi_config & III_A & 122 &   0 &  68 &   86.13 & 11.48
# 480 &   gurobi_config & III_B & 123 &   0 &  56 &   87.49 & 11.67

# %%
print_general_stats(df_chuffed, models, problems), print_general_stats(df_chuffed2, models, problems2)
# Out:
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 480 &  chuffed_config &   I_A &  60 &   0 & 154 &   40.57 &  5.41
# 480 &  chuffed_config &   I_B &  50 &   0 &  69 &   36.60 &  4.88
# 480 &  chuffed_config &  II_A &  58 &   0 & 145 &   38.57 &  5.14
# 480 &  chuffed_config &  II_B &  46 &   0 &  74 &   36.52 &  4.87
# 480 &  chuffed_config & III_A &  66 &   0 &  95 &   50.02 &  6.67
# 480 &  chuffed_config & III_B &  66 &   0 &  42 &   47.88 &  6.38
#
#
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 480 &  chuffed_config &   I_A & 100 &   0 & 271 &   67.11 &  8.95
# 480 &  chuffed_config &   I_B &  99 &   0 & 113 &   65.42 &  8.72
# 480 &  chuffed_config &  II_A & 104 &   0 & 158 &   70.33 &  9.38
# 480 &  chuffed_config &  II_B & 103 &   0 &  84 &   68.67 &  9.16
# 480 &  chuffed_config & III_A & 122 &   0 &  65 &   80.56 & 10.74
# 480 &  chuffed_config & III_B & 123 &   0 &  48 &   80.99 & 10.80
# (None, None)

# %%
print_general_stats(df_chuffed, models, problems_light), print_general_stats(df_chuffed2, models, problems2_light)
# Out:
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 300 &  chuffed_config &   I_A &  33 &   0 & 113 &   36.22 &  3.02
# 300 &  chuffed_config &   I_B &  29 &   0 &  39 &   32.15 &  2.68
# 300 &  chuffed_config &  II_A &  32 &   0 & 117 &   33.39 &  2.78
# 300 &  chuffed_config &  II_B &  26 &   0 &  41 &   33.88 &  2.82
# 300 &  chuffed_config & III_A &  38 &   0 &  77 &   47.84 &  3.99
# 300 &  chuffed_config & III_B &  39 &   0 &  29 &   46.13 &  3.84
#
#
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 300 &  chuffed_config &   I_A &  17 &   0 & 163 &   18.40 &  1.53
# 300 &  chuffed_config &   I_B &  16 &   0 &  46 &   17.59 &  1.47
# 300 &  chuffed_config &  II_A &  16 &   0 & 111 &   18.46 &  1.54
# 300 &  chuffed_config &  II_B &  14 &   0 &  41 &   17.03 &  1.42
# 300 &  chuffed_config & III_A &  18 &   0 &  37 &   21.69 &  1.81
# 300 &  chuffed_config & III_B &  19 &   0 &  25 &   21.95 &  1.83
# (None, None)

# %%
print_general_stats(df_chuffed, models, problems_medium), print_general_stats(df_chuffed2, models, problems2_medium)
# Out:
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 60 &  chuffed_config &   I_A &  14 &   0 &  26 &   71.47 &  1.19
# 60 &  chuffed_config &   I_B &  11 &   0 &  15 &   65.25 &  1.09
# 60 &  chuffed_config &  II_A &  13 &   0 &  21 &   66.44 &  1.11
# 60 &  chuffed_config &  II_B &  10 &   0 &  18 &   61.16 &  1.02
# 60 &  chuffed_config & III_A &  15 &   0 &  12 &   76.59 &  1.28
# 60 &  chuffed_config & III_B &  14 &   0 &  10 &   73.88 &  1.23
#
#
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 60 &  chuffed_config &   I_A &   5 &   0 &  32 &   32.15 &  0.54
# 60 &  chuffed_config &   I_B &   5 &   0 &  12 &   30.49 &  0.51
# 60 &  chuffed_config &  II_A &   5 &   0 &  22 &   33.96 &  0.57
# 60 &  chuffed_config &  II_B &   5 &   0 &  11 &   31.16 &  0.52
# 60 &  chuffed_config & III_A &  17 &   0 &   6 &   87.52 &  1.46
# 60 &  chuffed_config & III_B &  17 &   0 &   5 &   87.09 &  1.45
# (None, None)

# %%
print_general_stats(df_chuffed, models, problems_hard), print_general_stats(df_chuffed2, models, problems2_hard)
# Out:
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 120 &  chuffed_config &   I_A &  13 &   0 &  15 &   36.02 &  1.20
# 120 &  chuffed_config &   I_B &  10 &   0 &  15 &   33.40 &  1.11
# 120 &  chuffed_config &  II_A &  13 &   0 &   7 &   37.58 &  1.25
# 120 &  chuffed_config &  II_B &  10 &   0 &  15 &   30.83 &  1.03
# 120 &  chuffed_config & III_A &  13 &   0 &   6 &   42.20 &  1.41
# 120 &  chuffed_config & III_B &  13 &   0 &   3 &   39.27 &  1.31
#
#
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 120 &  chuffed_config &   I_A &  78 &   0 &  76 &  206.36 &  6.88
# 120 &  chuffed_config &   I_B &  78 &   0 &  55 &  202.46 &  6.75
# 120 &  chuffed_config &  II_A &  83 &   0 &  25 &  218.17 &  7.27
# 120 &  chuffed_config &  II_B &  84 &   0 &  32 &  216.52 &  7.22
# 120 &  chuffed_config & III_A &  87 &   0 &  22 &  224.24 &  7.47
# 120 &  chuffed_config & III_B &  87 &   0 &  18 &  225.54 &  7.52
# (None, None)

# %%
print_general_stats(df_cpsat, models, problems), print_general_stats(df_cpsat2, models, problems2)
# Out:
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 480 &    cpsat_config &   I_A & 139 & 139 & 157 &   94.67 & 12.62
# 480 &    cpsat_config &   I_B & 139 & 139 &  30 &   95.20 & 12.69
# 480 &    cpsat_config &  II_A & 140 & 140 &  92 &   94.53 & 12.60
# 480 &    cpsat_config &  II_B & 140 & 140 &  22 &   94.50 & 12.60
# 480 &    cpsat_config & III_A & 139 & 139 &  72 &   94.50 & 12.60
# 480 &    cpsat_config & III_B & 139 & 139 &  15 &   94.47 & 12.60
#
#
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 480 &    cpsat_config &   I_A &  89 &  89 & 170 &   60.22 &  8.03
# 480 &    cpsat_config &   I_B &  90 &  90 &  79 &   60.16 &  8.02
# 480 &    cpsat_config &  II_A &  89 &  89 &  81 &   59.66 &  7.95
# 480 &    cpsat_config &  II_B &  87 &  87 &  34 &   59.59 &  7.95
# 480 &    cpsat_config & III_A &  88 &  88 &  71 &   59.75 &  7.97
# 480 &    cpsat_config & III_B &  89 &  89 &  22 &   60.49 &  8.07
# (None, None)

# %%
print_general_stats(df_cpsat, models, problems_light), print_general_stats(df_cpsat2, models, problems2_light)
# Out:
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 300 &    cpsat_config &   I_A &  26 &  26 & 127 &   35.50 &  2.96
# 300 &    cpsat_config &   I_B &  26 &  26 &  27 &   35.80 &  2.98
# 300 &    cpsat_config &  II_A &  27 &  27 &  74 &   36.01 &  3.00
# 300 &    cpsat_config &  II_B &  26 &  26 &  20 &   35.21 &  2.93
# 300 &    cpsat_config & III_A &  26 &  26 &  54 &   36.11 &  3.01
# 300 &    cpsat_config & III_B &  26 &  26 &  13 &   35.65 &  2.97
#
#
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 300 &    cpsat_config &   I_A &  15 &  15 & 130 &   17.22 &  1.43
# 300 &    cpsat_config &   I_B &  16 &  16 &  68 &   17.86 &  1.49
# 300 &    cpsat_config &  II_A &  15 &  15 &  50 &   17.24 &  1.44
# 300 &    cpsat_config &  II_B &  14 &  14 &  23 &   17.17 &  1.43
# 300 &    cpsat_config & III_A &  14 &  14 &  57 &   16.92 &  1.41
# 300 &    cpsat_config & III_B &  15 &  15 &  19 &   17.73 &  1.48
# (None, None)

# %%
print_general_stats(df_cpsat, models, problems_medium), print_general_stats(df_cpsat2, models, problems2_medium)
# Out:
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 60 &    cpsat_config &   I_A &  23 &  23 &  19 &  122.85 &  2.05
# 60 &    cpsat_config &   I_B &  23 &  23 &   3 &  123.57 &  2.06
# 60 &    cpsat_config &  II_A &  23 &  23 &  10 &  121.14 &  2.02
# 60 &    cpsat_config &  II_B &  23 &  23 &   2 &  121.33 &  2.02
# 60 &    cpsat_config & III_A &  23 &  23 &   7 &  121.30 &  2.02
# 60 &    cpsat_config & III_B &  23 &  23 &   2 &  121.66 &  2.03
#
#
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 60 &    cpsat_config &   I_A &   0 &   0 &  21 &   17.25 &  0.29
# 60 &    cpsat_config &   I_B &   0 &   0 &   7 &   16.38 &  0.27
# 60 &    cpsat_config &  II_A &   0 &   0 &  17 &   16.88 &  0.28
# 60 &    cpsat_config &  II_B &   0 &   0 &   9 &   16.29 &  0.27
# 60 &    cpsat_config & III_A &   0 &   0 &   8 &   16.95 &  0.28
# 60 &    cpsat_config & III_B &   0 &   0 &   1 &   16.62 &  0.28
# (None, None)

# %%
print_general_stats(df_cpsat, models, problems_hard), print_general_stats(df_cpsat2, models, problems2_hard)
# Out:
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 120 &    cpsat_config &   I_A &  90 &  90 &  11 &  228.52 &  7.62
# 120 &    cpsat_config &   I_B &  90 &  90 &   0 &  229.50 &  7.65
# 120 &    cpsat_config &  II_A &  90 &  90 &   8 &  227.51 &  7.58
# 120 &    cpsat_config &  II_B &  91 &  91 &   0 &  229.33 &  7.64
# 120 &    cpsat_config & III_A &  90 &  90 &  11 &  227.10 &  7.57
# 120 &    cpsat_config & III_B &  90 &  90 &   0 &  227.91 &  7.60
#
#
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 120 &    cpsat_config &   I_A &  74 &  74 &  19 &  189.21 &  6.31
# 120 &    cpsat_config &   I_B &  74 &  74 &   4 &  187.81 &  6.26
# 120 &    cpsat_config &  II_A &  74 &  74 &  14 &  187.09 &  6.24
# 120 &    cpsat_config &  II_B &  73 &  73 &   2 &  187.31 &  6.24
# 120 &    cpsat_config & III_A &  74 &  74 &   6 &  188.24 &  6.27
# 120 &    cpsat_config & III_B &  74 &  74 &   2 &  189.35 &  6.31
# (None, None)

# %%
print_general_stats(df_gurobi, models, problems), print_general_stats(df_gurobi2, models, problems2)
# Out:
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 480 &   gurobi_config &   I_A & 160 &   0 & 230 &  109.84 & 14.65
# 480 &   gurobi_config &   I_B & 160 &   0 & 150 &  110.03 & 14.67
# 480 &   gurobi_config &  II_A & 159 &   0 & 218 &  109.48 & 14.60
# 480 &   gurobi_config &  II_B & 159 &   0 & 159 &  109.27 & 14.57
# 480 &   gurobi_config & III_A & 160 &   0 & 197 &  109.68 & 14.62
# 480 &   gurobi_config & III_B & 160 &   0 & 138 &  109.84 & 14.64
#
#
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 480 &   gurobi_config &   I_A & 123 &   0 & 221 &   86.71 & 11.56
# 480 &   gurobi_config &   I_B & 124 &   0 & 134 &   87.22 & 11.63
# 480 &   gurobi_config &  II_A & 122 &   0 & 178 &   87.33 & 11.64
# 480 &   gurobi_config &  II_B & 121 &   0 & 122 &   86.37 & 11.52
# 480 &   gurobi_config & III_A & 122 &   0 & 166 &   86.13 & 11.48
# 480 &   gurobi_config & III_B & 123 &   0 & 118 &   87.49 & 11.67
# (None, None)

# %%
print_general_stats(df_gurobi, models, problems_light), print_general_stats(df_gurobi2, models, problems2_light)
# Out:
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 300 &   gurobi_config &   I_A &  34 &   0 & 133 &   41.80 &  3.48
# 300 &   gurobi_config &   I_B &  34 &   0 &  57 &   41.71 &  3.48
# 300 &   gurobi_config &  II_A &  34 &   0 & 124 &   41.29 &  3.44
# 300 &   gurobi_config &  II_B &  34 &   0 &  58 &   41.01 &  3.42
# 300 &   gurobi_config & III_A &  33 &   0 &  93 &   41.41 &  3.45
# 300 &   gurobi_config & III_B &  33 &   0 &  45 &   41.69 &  3.47
#
#
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 300 &   gurobi_config &   I_A &  26 &   0 & 149 &   30.76 &  2.56
# 300 &   gurobi_config &   I_B &  28 &   0 &  61 &   32.00 &  2.67
# 300 &   gurobi_config &  II_A &  27 &   0 &  99 &   31.95 &  2.66
# 300 &   gurobi_config &  II_B &  26 &   0 &  48 &   30.86 &  2.57
# 300 &   gurobi_config & III_A &  26 &   0 &  81 &   31.10 &  2.59
# 300 &   gurobi_config & III_B &  27 &   0 &  48 &   32.23 &  2.69
# (None, None)

# %%
print_general_stats(df_gurobi, models, problems_medium), print_general_stats(df_gurobi2, models, problems2_medium)
# Out:
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 60 &   gurobi_config &   I_A &  28 &   0 &  38 &  148.68 &  2.48
# 60 &   gurobi_config &   I_B &  28 &   0 &  32 &  148.05 &  2.47
# 60 &   gurobi_config &  II_A &  28 &   0 &  32 &  148.21 &  2.47
# 60 &   gurobi_config &  II_B &  28 &   0 &  33 &  148.45 &  2.47
# 60 &   gurobi_config & III_A &  28 &   0 &  35 &  149.25 &  2.49
# 60 &   gurobi_config & III_B &  28 &   0 &  30 &  148.60 &  2.48
#
#
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 60 &   gurobi_config &   I_A &   7 &   0 &  13 &   67.75 &  1.13
# 60 &   gurobi_config &   I_B &   6 &   0 &  17 &   66.99 &  1.12
# 60 &   gurobi_config &  II_A &   6 &   0 &  22 &   66.97 &  1.12
# 60 &   gurobi_config &  II_B &   6 &   0 &  11 &   67.01 &  1.12
# 60 &   gurobi_config & III_A &   7 &   0 &  20 &   66.07 &  1.10
# 60 &   gurobi_config & III_B &   6 &   0 &   9 &   67.70 &  1.13
# (None, None)

# %%
print_general_stats(df_gurobi, models, problems_hard), print_general_stats(df_gurobi2, models, problems2_hard)
# Out:
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 120 &   gurobi_config &   I_A &  98 &   0 &  59 &  260.53 &  8.68
# 120 &   gurobi_config &   I_B &  98 &   0 &  61 &  261.82 &  8.73
# 120 &   gurobi_config &  II_A &  97 &   0 &  62 &  260.58 &  8.69
# 120 &   gurobi_config &  II_B &  97 &   0 &  68 &  260.34 &  8.68
# 120 &   gurobi_config & III_A &  99 &   0 &  69 &  260.60 &  8.69
# 120 &   gurobi_config & III_B &  99 &   0 &  63 &  260.81 &  8.69
#
#
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 120 &   gurobi_config &   I_A &  90 &   0 &  59 &  236.07 &  7.87
# 120 &   gurobi_config &   I_B &  90 &   0 &  56 &  235.38 &  7.85
# 120 &   gurobi_config &  II_A &  89 &   0 &  57 &  235.94 &  7.86
# 120 &   gurobi_config &  II_B &  89 &   0 &  63 &  234.83 &  7.83
# 120 &   gurobi_config & III_A &  89 &   0 &  65 &  233.74 &  7.79
# 120 &   gurobi_config & III_B &  90 &   0 &  61 &  235.53 &  7.85
# (None, None)

# %%
print_general_stats_enumerate(df_chuffed, models, nb_target_plates, size_target_plates, nb_source_plates)
# Out:
# nb_target_plates: 2 size_target_plates: 2 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   4 &    0.31 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   1 &    0.32 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   7 &    0.31 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   0 &    0.33 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   1 &    0.32 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   2 &    0.33 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 2 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   4 &    0.36 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   1 &    0.40 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   3 &    0.36 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   0 &    0.40 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   2 &    0.37 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   0 &    0.43 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 2 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   5 &    0.35 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   0 &    0
#
#
#
#
# nb_target_plates: 10 size_target_plates: 6 nb_source_plates: 10 nb_problems: 0
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 0 &  chuffed_config &   I_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &   I_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_B &   0 &   0 &   0 &     nan &  0.00
#
#
#
#
# nb_target_plates: 10 size_target_plates: 8 nb_source_plates: 2 nb_problems: 0
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 0 &  chuffed_config &   I_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &   I_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_B &   0 &   0 &   0 &     nan &  0.00
#
#
#
#
# nb_target_plates: 10 size_target_plates: 8 nb_source_plates: 5 nb_problems: 0
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 0 &  chuffed_config &   I_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &   I_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_B &   0 &   0 &   0 &     nan &  0.00
#
#
#
#
# nb_target_plates: 10 size_target_plates: 8 nb_source_plates: 10 nb_problems: 0
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 0 &  chuffed_config &   I_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &   I_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_B &   0 &   0 &   0 &     nan &  0.00
#
#
#
#
# nb_target_plates: 15 size_target_plates: 2 nb_source_plates: 2 nb_problems: 0
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 0 &  chuffed_config &   I_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &   I_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_B &   0 &   0 &   0 &     nan &  0.00
#
#
#
#
# nb_target_plates: 15 size_target_plates: 2 nb_source_plates: 5 nb_problems: 0
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 0 &  chuffed_config &   I_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &   I_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_B &   0 &   0 &   0 &     nan &  0.00
# <ipython-input-122-14fa96ffeeca>:33: RuntimeWarning: invalid value encountered in scalar divide
#   print(str(nb_problems) + ' & ' + '%15s' % solver + ' & ' + '%5s' % model + ' & ' + '%3s' % str(collect_timeouts) + ' & ' + '%3s' % str(collect_no_solutions) + ' & ' + '%3s' % str(best_result_per_problem[(solver,model)]) + ' & ' + '%7s' % "{:.2f}".format(total_time_all / nb_problems) + ' & ' + '%5s' % "{:.2f}".format(total_time_all / 3600))
# nb_target_plates: 15 size_target_plates: 2 nb_source_plates: 10 nb_problems: 0
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 0 &  chuffed_config &   I_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &   I_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_B &   0 &   0 &   0 &     nan &  0.00
#
#
#
#
# nb_target_plates: 15 size_target_plates: 4 nb_source_plates: 2 nb_problems: 0
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 0 &  chuffed_config &   I_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &   I_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_B &   0 &   0 &   0 &     nan &  0.00
#
#
#
#
# nb_target_plates: 15 size_target_plates: 4 nb_source_plates: 5 nb_problems: 0
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 0 &  chuffed_config &   I_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &   I_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_B &   0 &   0 &   0 &     nan &  0.00
#
#
#
#
# nb_target_plates: 15 size_target_plates: 4 nb_source_plates: 10 nb_problems: 0
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 0 &  chuffed_config &   I_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &   I_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_B &   0 &   0 &   0 &     nan &  0.00
#
#
#
#
# nb_target_plates: 15 size_target_plates: 6 nb_source_plates: 2 nb_problems: 0
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 0 &  chuffed_config &   I_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &   I_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_B &   0 &   0 &   0 &     nan &  0.00
#
#
#
#
# nb_target_plates: 15 size_target_plates: 6 nb_source_plates: 5 nb_problems: 0
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 0 &  chuffed_config &   I_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &   I_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_B &   0 &   0 &   0 &     nan &  0.00
#
#
#
#
# nb_target_plates: 15 size_target_plates: 6 nb_source_plates: 10 nb_problems: 0
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 0 &  chuffed_config &   I_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &   I_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_B &   0 &   0 &   0 &     nan &  0.00
#
#
#
#
# nb_target_plates: 15 size_target_plates: 8 nb_source_plates: 2 nb_problems: 0
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 0 &  chuffed_config &   I_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &   I_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_B &   0 &   0 &   0 &     nan &  0.00
#
#
#
#
# nb_target_plates: 15 size_target_plates: 8 nb_source_plates: 5 nb_problems: 0
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 0 &  chuffed_config &   I_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &   I_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_B &   0 &   0 &   0 &     nan &  0.00
#
#
#
#
# nb_target_plates: 15 size_target_plates: 8 nb_source_plates: 10 nb_problems: 0
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 0 &  chuffed_config &   I_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &   I_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config &  II_B &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_A &   0 &   0 &   0 &     nan &  0.00
# 0 &  chuffed_config & III_B &   0 &   0 &   0 &     nan &  0.00

# %%
print_general_stats_enumerate(df_cpsat, models, nb_target_plates, size_target_plates, nb_source_plates)
# Out:
# nb_target_plates: 2 size_target_plates: 2 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   6 &    0.27 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   1 &    0.28 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   3 &    0.28 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   1 &    0.28 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   6 &    0.27 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.28 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 2 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   6 &    0.29 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.36 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   5 &    0.31 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.37 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   4 &    0.29 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.37 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 2 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   3 &    0.31 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.40 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   5 &    0.28 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.40 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   5 &    0.29 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.40 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 4 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   2 &    0.36 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   1 &    0.38 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   5 &    0.35 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.39 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   4 &    0.36 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   1 &    0.38 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 4 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   3 &    0.38 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   1 &    0.42 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   3 &    0.38 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.44 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   4 &    0.38 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.43 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 4 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   4 &    0.38 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.47 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   7 &    0.38 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.46 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   2 &    0.40 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.48 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 6 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   2 &    0.38 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   1 &    0.40 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   1 &    0.40 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   4 &    0.39 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   5 &    0.38 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.41 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 6 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   1 &    0.39 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   1 &    0.42 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   5 &    0.39 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.43 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   5 &    0.38 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.45 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 6 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   3 &    0.39 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.47 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   5 &    0.39 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.47 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   3 &    0.39 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.49 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 8 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   5 &    0.37 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   2 &    0.40 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   1 &    0.38 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.39 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   3 &    0.38 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   1 &    0.40 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 8 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   6 &    0.36 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.42 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   2 &    0.39 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.44 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   3 &    0.39 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.42 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 8 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   5 &    0.39 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   1 &    0.47 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   5 &    0.41 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.49 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   3 &    0.42 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   2 &    0.45 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 2 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   9 &    0.34 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   1 &    0.43 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   1 &    0.41 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.44 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   0 &    0.42 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.43 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 2 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   7 &    0.34 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.43 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   3 &    0.37 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.45 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   0 &    0.38 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.46 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 2 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   7 &    0.39 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.64 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   5 &    0.41 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.64 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   0 &    0.44 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.65 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 4 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   8 &    0.33 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.45 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   1 &    0.40 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   2 &    0.42 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   0 &    0.41 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.49 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 4 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &  10 &    0.34 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.45 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   1 &    0.39 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.48 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   2 &    0.40 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.49 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 4 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   4 &    0.73 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    1.04 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   3 &    0.90 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    1.07 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   3 &    0.82 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    1.05 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 6 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   4 &    0.51 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   2 &    0.54 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   2 &    0.53 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   1 &    0.59 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   1 &    0.57 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.67 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 6 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   4 &    0.93 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   1 &    1.03 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   1 &    0.98 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    1.05 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   3 &    0.86 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   1 &    1.10 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 6 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   2 &    4.64 &  0.01
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &   19.56 &  0.05
# 10 &    cpsat_config &  II_A &   0 &   0 &   4 &    5.30 &  0.01
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    8.15 &  0.02
# 10 &    cpsat_config & III_A &   0 &   0 &   4 &    2.21 &  0.01
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    3.39 &  0.01
#
#
#
#
# nb_target_plates: 5 size_target_plates: 8 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   7 &    0.59 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   2 &    0.61 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   1 &    0.59 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.65 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   0 &    0.66 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.75 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 8 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   5 &    0.91 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   1 &    1.07 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   4 &    0.93 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   1 &    1.11 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   1 &    1.04 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    1.17 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 8 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   1 &   1 &   4 &   66.69 &  0.19
# 10 &    cpsat_config &   I_B &   1 &   1 &   0 &   63.23 &  0.18
# 10 &    cpsat_config &  II_A &   1 &   1 &   1 &   53.37 &  0.15
# 10 &    cpsat_config &  II_B &   2 &   2 &   0 &   71.99 &  0.20
# 10 &    cpsat_config & III_A &   1 &   1 &   4 &   51.77 &  0.14
# 10 &    cpsat_config & III_B &   1 &   1 &   0 &   60.16 &  0.17
#
#
#
#
# nb_target_plates: 10 size_target_plates: 2 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   6 &    0.65 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   1 &    0.81 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   2 &    0.74 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   1 &    0.72 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   0 &    0.81 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.91 &  0.00
#
#
#
#
# nb_target_plates: 10 size_target_plates: 2 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   3 &   3 &   1 &   96.29 &  0.27
# 10 &    cpsat_config &   I_B &   3 &   3 &   2 &   96.20 &  0.27
# 10 &    cpsat_config &  II_A &   3 &   3 &   0 &   97.47 &  0.27
# 10 &    cpsat_config &  II_B &   3 &   3 &   1 &   97.41 &  0.27
# 10 &    cpsat_config & III_A &   3 &   3 &   1 &   96.47 &  0.27
# 10 &    cpsat_config & III_B &   3 &   3 &   2 &   97.09 &  0.27
#
#
#
#
# nb_target_plates: 10 size_target_plates: 2 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   5 &   5 &   0 &  179.03 &  0.50
# 10 &    cpsat_config &   I_B &   5 &   5 &   1 &  179.96 &  0.50
# 10 &    cpsat_config &  II_A &   5 &   5 &   0 &  184.82 &  0.51
# 10 &    cpsat_config &  II_B &   5 &   5 &   2 &  171.69 &  0.48
# 10 &    cpsat_config & III_A &   5 &   5 &   1 &  186.42 &  0.52
# 10 &    cpsat_config & III_B &   5 &   5 &   1 &  177.60 &  0.49
#
#
#
#
# nb_target_plates: 10 size_target_plates: 4 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   9 &    1.28 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   1 &    1.44 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   0 &    1.50 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    1.61 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   0 &    1.78 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    1.96 &  0.01
#
#
#
#
# nb_target_plates: 10 size_target_plates: 4 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   6 &   6 &   0 &  196.66 &  0.55
# 10 &    cpsat_config &   I_B &   6 &   6 &   1 &  197.30 &  0.55
# 10 &    cpsat_config &  II_A &   6 &   6 &   2 &  193.84 &  0.54
# 10 &    cpsat_config &  II_B &   6 &   6 &   1 &  194.51 &  0.54
# 10 &    cpsat_config & III_A &   6 &   6 &   1 &  197.82 &  0.55
# 10 &    cpsat_config & III_B &   6 &   6 &   0 &  198.30 &  0.55
#
#
#
#
# nb_target_plates: 10 size_target_plates: 4 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &   I_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_B &  10 &  10 &   0 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 10 size_target_plates: 6 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   6 &    1.66 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   2 &    1.81 &  0.01
# 10 &    cpsat_config &  II_A &   0 &   0 &   2 &    1.85 &  0.01
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    1.91 &  0.01
# 10 &    cpsat_config & III_A &   0 &   0 &   0 &    2.27 &  0.01
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    2.49 &  0.01
#
#
#
#
# nb_target_plates: 10 size_target_plates: 6 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   8 &   8 &   0 &  258.52 &  0.72
# 10 &    cpsat_config &   I_B &   8 &   8 &   0 &  255.24 &  0.71
# 10 &    cpsat_config &  II_A &   8 &   8 &   1 &  253.71 &  0.70
# 10 &    cpsat_config &  II_B &   8 &   8 &   0 &  252.44 &  0.70
# 10 &    cpsat_config & III_A &   8 &   8 &   0 &  250.29 &  0.70
# 10 &    cpsat_config & III_B &   8 &   8 &   1 &  249.17 &  0.69
#
#
#
#
# nb_target_plates: 10 size_target_plates: 6 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &   I_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_B &  10 &  10 &   0 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 10 size_target_plates: 8 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   3 &    2.18 &  0.01
# 10 &    cpsat_config &   I_B &   0 &   0 &   2 &    2.41 &  0.01
# 10 &    cpsat_config &  II_A &   0 &   0 &   3 &    2.13 &  0.01
# 10 &    cpsat_config &  II_B &   0 &   0 &   2 &    2.24 &  0.01
# 10 &    cpsat_config & III_A &   0 &   0 &   0 &    2.58 &  0.01
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    2.74 &  0.01
#
#
#
#
# nb_target_plates: 10 size_target_plates: 8 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   9 &   9 &   0 &  279.75 &  0.78
# 10 &    cpsat_config &   I_B &   9 &   9 &   0 &  286.34 &  0.80
# 10 &    cpsat_config &  II_A &   9 &   9 &   1 &  276.97 &  0.77
# 10 &    cpsat_config &  II_B &   9 &   9 &   0 &  278.39 &  0.77
# 10 &    cpsat_config & III_A &   9 &   9 &   0 &  277.40 &  0.77
# 10 &    cpsat_config & III_B &   9 &   9 &   0 &  279.72 &  0.78
#
#
#
#
# nb_target_plates: 10 size_target_plates: 8 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &   I_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_B &  10 &  10 &   0 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 15 size_target_plates: 2 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   4 &   13.81 &  0.04
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &   14.11 &  0.04
# 10 &    cpsat_config &  II_A &   0 &   0 &   1 &   15.20 &  0.04
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &   14.88 &  0.04
# 10 &    cpsat_config & III_A &   0 &   0 &   2 &   13.85 &  0.04
# 10 &    cpsat_config & III_B &   0 &   0 &   3 &   12.87 &  0.04
#
#
#
#
# nb_target_plates: 15 size_target_plates: 2 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   9 &   9 &   1 &  290.91 &  0.81
# 10 &    cpsat_config &   I_B &   9 &   9 &   0 &  299.04 &  0.83
# 10 &    cpsat_config &  II_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_B &   9 &   9 &   0 &  292.80 &  0.81
# 10 &    cpsat_config & III_A &   9 &   9 &   0 &  297.30 &  0.83
# 10 &    cpsat_config & III_B &   9 &   9 &   0 &  293.17 &  0.81
#
#
#
#
# nb_target_plates: 15 size_target_plates: 2 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   9 &   9 &   1 &  270.38 &  0.75
# 10 &    cpsat_config &   I_B &   9 &   9 &   0 &  270.70 &  0.75
# 10 &    cpsat_config &  II_A &   9 &   9 &   0 &  270.70 &  0.75
# 10 &    cpsat_config &  II_B &   9 &   9 &   0 &  270.57 &  0.75
# 10 &    cpsat_config & III_A &   9 &   9 &   0 &  270.39 &  0.75
# 10 &    cpsat_config & III_B &   9 &   9 &   0 &  270.49 &  0.75
#
#
#
#
# nb_target_plates: 15 size_target_plates: 4 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   2 &   30.21 &  0.08
# 10 &    cpsat_config &   I_B &   0 &   0 &   2 &   31.24 &  0.09
# 10 &    cpsat_config &  II_A &   0 &   0 &   2 &   31.26 &  0.09
# 10 &    cpsat_config &  II_B &   0 &   0 &   2 &   30.30 &  0.08
# 10 &    cpsat_config & III_A &   0 &   0 &   0 &   33.81 &  0.09
# 10 &    cpsat_config & III_B &   0 &   0 &   2 &   31.74 &  0.09
#
#
#
#
# nb_target_plates: 15 size_target_plates: 4 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   9 &   9 &   1 &  270.15 &  0.75
# 10 &    cpsat_config &   I_B &   9 &   9 &   0 &  270.22 &  0.75
# 10 &    cpsat_config &  II_A &   9 &   9 &   0 &  270.56 &  0.75
# 10 &    cpsat_config &  II_B &   9 &   9 &   0 &  270.70 &  0.75
# 10 &    cpsat_config & III_A &   9 &   9 &   0 &  270.43 &  0.75
# 10 &    cpsat_config & III_B &   9 &   9 &   0 &  270.31 &  0.75
#
#
#
#
# nb_target_plates: 15 size_target_plates: 4 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &   I_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_B &  10 &  10 &   0 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 15 size_target_plates: 6 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   3 &   60.96 &  0.17
# 10 &    cpsat_config &   I_B &   0 &   0 &   1 &   63.64 &  0.18
# 10 &    cpsat_config &  II_A &   0 &   0 &   2 &   62.23 &  0.17
# 10 &    cpsat_config &  II_B &   0 &   0 &   2 &   60.33 &  0.17
# 10 &    cpsat_config & III_A &   0 &   0 &   1 &   63.27 &  0.18
# 10 &    cpsat_config & III_B &   0 &   0 &   1 &   63.63 &  0.18
#
#
#
#
# nb_target_plates: 15 size_target_plates: 6 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &   I_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_B &  10 &  10 &   0 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 15 size_target_plates: 6 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &   I_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_B &  10 &  10 &   0 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 15 size_target_plates: 8 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   3 &  110.88 &  0.31
# 10 &    cpsat_config &   I_B &   0 &   0 &   2 &  104.75 &  0.29
# 10 &    cpsat_config &  II_A &   0 &   0 &   2 &  105.48 &  0.29
# 10 &    cpsat_config &  II_B &   0 &   0 &   2 &  103.58 &  0.29
# 10 &    cpsat_config & III_A &   0 &   0 &   1 &  107.02 &  0.30
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &  106.38 &  0.30
#
#
#
#
# nb_target_plates: 15 size_target_plates: 8 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &   I_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_B &  10 &  10 &   0 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 15 size_target_plates: 8 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &   I_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_B &  10 &  10 &   0 &  300.00 &  0.83

# %%
print_general_stats_enumerate(df_gurobi, models, nb_target_plates, size_target_plates, nb_source_plates)
# Out:
# nb_target_plates: 2 size_target_plates: 2 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   7 &    0.27 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.30 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   7 &    0.27 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &    0.30 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   5 &    0.27 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.30 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 2 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   5 &    0.33 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   2 &    0.35 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   3 &    0.33 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   1 &    0.35 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   4 &    0.33 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.36 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 2 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   4 &    0.30 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.39 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   8 &    0.28 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &    0.40 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   2 &    0.30 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.39 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 4 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   4 &    0.36 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   1 &    0.38 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   1 &    0.37 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   1 &    0.38 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   5 &    0.36 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.40 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 4 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   5 &    0.39 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.43 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   4 &    0.39 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   1 &    0.42 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   2 &    0.39 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.44 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 4 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   3 &    0.39 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.49 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   0 &    0.39 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &    0.48 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   8 &    0.37 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.47 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 6 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   4 &    0.38 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   2 &    0.41 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   4 &    0.39 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   1 &    0.41 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   7 &    0.39 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.41 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 6 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   8 &    0.38 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.44 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   3 &    0.39 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &    0.44 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   1 &    0.40 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   1 &    0.43 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 6 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   3 &    0.39 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.50 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   6 &    0.37 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &    0.48 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   2 &    0.40 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.48 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 8 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   4 &    0.37 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.40 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   3 &    0.39 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &    0.39 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   4 &    0.37 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.41 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 8 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   5 &    0.38 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   1 &    0.42 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   5 &    0.39 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &    0.44 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   1 &    0.40 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.44 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 8 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   2 &    0.42 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.47 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   7 &    0.39 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   1 &    0.47 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   2 &    0.40 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.51 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 2 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   3 &    0.39 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   1 &    0.43 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   7 &    0.37 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   1 &    0.43 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   1 &    0.41 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.46 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 2 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   7 &    0.40 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.51 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   3 &    0.41 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &    0.51 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   1 &    0.44 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.57 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 2 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   5 &    0.74 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.97 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &
&  300.00 &  0.83
# 10 &   gurobi_config & III_B &  10 &   0 &   5 &  300.00 &  0.83

# %%
print_general_stats_enumerate(df_chuffed2, models, nb_target_plates, size_target_plates, nb_source_plates)
# Out:
# nb_target_plates: 2 size_target_plates: 2 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   1 &    0.50 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   1 &    0.46 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   4 &    0.46 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   2 &    0.46 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   2 &    0.45 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   2 &    0.46 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 2 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   5 &    0.42 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   1 &    0.45 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   4 &    0.42 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   1 &    0.45 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   1 &    0.44 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   1 &    0.47 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 2 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   4 &    0.47 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   0 &    0.52 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   5 &    0.46 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   1 &    0.49 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   2 &    0.48 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   1 &    0.52 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 4 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   3 &    0.49 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   1 &    0.49 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   3 &    0.48 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   0 &    0.49 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   1 &    0.48 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   3 &    0.48 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 4 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   2 &    0.49 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   1 &    0.54 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   7 &    0.48 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   0 &    0.53 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   1 &    0.49 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   0 &    0.54 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 4 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   5 &    0.41 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   0 &    0.49 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   6 &    0.41 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   0 &    0.49 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   5 &    0.43 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   1 &    0.50 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 6 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   4 &    0.44 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   1 &    0.47 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   2 &    0.47 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   1 &    0.46 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   1 &    0.46 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   2 &    0.46 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 6 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   3 &    0.48 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   0 &    0.51 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   6 &    0.45 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   0 &    0.52 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   2 &    0.48 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   1 &    0.52 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 6 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   7 &    0.50 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   0 &    0.59 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   6 &    0.48 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   0 &    0.59 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   2 &    0.50 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   0 &    0.61 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 8 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   3 &    0.49 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   3 &    0.49 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   2 &    0.49 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   3 &    0.49 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   2 &    0.52 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   2 &    0.51 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 8 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   6 &    0.43 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   2 &    0.47 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   3 &    0.45 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   0 &    0.49 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   3 &    0.45 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   0 &    0.51 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 8 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   7 &    0.48 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   0 &    0.57 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   2 &    0.49 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   0 &    0.58 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   3 &    0.47 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   0 &    0.57 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 2 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   2 &    0.52 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   2 &    0.50 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   7 &    0.48 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   1 &    0.50 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   1 &    0.53 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   1 &    0.54 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 2 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   3 &    0.54 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   2 &    0.58 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   8 &    0.54 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   0 &    0.64 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   0 &    0.57 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   0 &    0.71 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 2 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   5 &    0.50 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   0 &    0.73 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   6 &    0.50 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   0 &    0.71 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   1 &    0.53 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   0 &    0.75 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 4 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   6 &    0.42 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   2 &    0.45 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   3 &    0.43 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   1 &    0.49 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   1 &    0.50 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   0 &    0.49 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 4 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   3 &    0.53 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   1 &    0.61 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   4 &    0.53 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   1 &    0.62 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   1 &    0.57 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   0 &    0.67 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 4 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   3 &    1.64 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   2 &    1.44 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   3 &    2.57 &  0.01
# 10 &  chuffed_config &  II_B &   0 &   0 &   2 &    1.46 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   0 &    2.20 &  0.01
# 10 &  chuffed_config & III_B &   0 &   0 &   0 &    2.22 &  0.01
#
#
#
#
# nb_target_plates: 5 size_target_plates: 6 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   7 &    0.45 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   1 &    0.47 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   4 &    0.46 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   3 &    0.47 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   0 &    0.50 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   0 &    0.54 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 6 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   5 &    0.48 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   0 &    0.57 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   7 &    0.48 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   0 &    0.57 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   0 &    0.58 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   0 &    0.70 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 6 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   1 &   18.57 &  0.05
# 10 &  chuffed_config &   I_B &   0 &   0 &   2 &    6.53 &  0.02
# 10 &  chuffed_config &  II_A &   0 &   0 &   0 &   25.65 &  0.07
# 10 &  chuffed_config &  II_B &   0 &   0 &   7 &    5.29 &  0.01
# 10 &  chuffed_config & III_A &   0 &   0 &   0 &   27.43 &  0.08
# 10 &  chuffed_config & III_B &   0 &   0 &   0 &   34.00 &  0.09
#
#
#
#
# nb_target_plates: 5 size_target_plates: 8 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   7 &    0.43 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   2 &    0.44 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   4 &    0.45 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   1 &    0.47 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   0 &    0.51 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   0 &    0.53 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 8 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   8 &    0.54 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   0 &    0.66 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   3 &    0.56 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   0 &    0.66 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   0 &    0.66 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   0 &    0.80 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 8 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   1 &   48.53 &  0.13
# 10 &  chuffed_config &   I_B &   0 &   0 &   3 &    9.90 &  0.03
# 10 &  chuffed_config &  II_A &   1 &   0 &   0 &   58.36 &  0.16
# 10 &  chuffed_config &  II_B &   0 &   0 &   6 &    8.42 &  0.02
# 10 &  chuffed_config & III_A &   2 &   0 &   0 &   78.40 &  0.22
# 10 &  chuffed_config & III_B &   2 &   0 &   0 &   83.69 &  0.23
#
#
#
#
# nb_target_plates: 10 size_target_plates: 2 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   6 &    0.46 &  0.00
# 10 &  chuffed_config &   I_B &   0 &   0 &   1 &    0.50 &  0.00
# 10 &  chuffed_config &  II_A &   0 &   0 &   4 &    0.49 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   2 &    0.52 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   0 &    0.64 &  0.00
# 10 &  chuffed_config & III_B &   0 &   0 &   0 &    0.64 &  0.00
#
#
#
#
# nb_target_plates: 10 size_target_plates: 2 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   0 &   0 &   4 &    2.79 &  0.01
# 10 &  chuffed_config &   I_B &   0 &   0 &   2 &    2.90 &  0.01
# 10 &  chuffed_config &  II_A &   0 &   0 &   2 &    1.74 &  0.00
# 10 &  chuffed_config &  II_B &   0 &   0 &   2 &    1.71 &  0.00
# 10 &  chuffed_config & III_A &   0 &   0 &   0 &   49.00 &  0.14
# 10 &  chuffed_config & III_B &   1 &   0 &   0 &   64.30 &  0.18
#
#
#
#
# nb_target_plates: 10 size_target_plates: 2 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   1 &   0 &   5 &   40.26 &  0.11
# 10 &  chuffed_config &   I_B &   1 &   0 &   0 &   41.31 &  0.11
# 10 &  chuffed_config &  II_A &   1 &   0 &   1 &   54.95 &  0.15
# 10 &  chuffed_config &  II_B &   0 &   0 &   2 
#
#
#
#
# nb_target_plates: 15 size_target_plates: 8 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &   9 &   0 &   8 &  280.60 &  0.78
# 10 &  chuffed_config &   I_B &   9 &   0 &   9 &  276.32 &  0.77
# 10 &  chuffed_config &  II_A &  10 &   0 &   0 &  300.00 &  0.83
# 10 &  chuffed_config &  II_B &  10 &   0 &   2 &  300.00 &  0.83
# 10 &  chuffed_config & III_A &   9 &   0 &   4 &  295.16 &  0.82
# 10 &  chuffed_config & III_B &  10 &   0 &   3 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 15 size_target_plates: 8 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &  chuffed_config &   I_A &  10 &   0 &   9 &  300.00 &  0.83
# 10 &  chuffed_config &   I_B &  10 &   0 &   5 &  300.00 &  0.83
# 10 &  chuffed_config &  II_A &  10 &   0 &   0 &  300.00 &  0.83
# 10 &  chuffed_config &  II_B &  10 &   0 &   0 &  300.00 &  0.83
# 10 &  chuffed_config & III_A &  10 &   0 &   1 &  300.00 &  0.83
# 10 &  chuffed_config & III_B &  10 &   0 &   0 &  300.00 &  0.83

# %%
print_general_stats_enumerate(df_cpsat2, models, nb_target_plates, size_target_plates, nb_source_plates)
# Out:
# nb_target_plates: 2 size_target_plates: 2 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   2 &    0.43 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   8 &    0.25 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   2 &    0.27 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   5 &    0.26 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   2 &    0.27 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   7 &    0.25 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 2 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   4 &    0.27 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.29 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   5 &    0.26 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.29 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   6 &    0.26 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.29 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 2 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   9 &    0.34 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.38 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   3 &    0.35 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.38 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   5 &    0.34 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   1 &    0.38 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 4 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   5 &    0.36 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   2 &    0.38 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   0 &    0.38 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   1 &    0.38 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   1 &    0.38 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   1 &    0.39 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 4 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   3 &    0.39 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   1 &    0.42 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   3 &    0.39 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   1 &    0.41 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   2 &    0.39 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.42 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 4 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   6 &    0.39 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.45 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   4 &    0.39 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.43 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   3 &    0.40 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.45 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 6 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   2 &    0.38 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   1 &    0.39 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   2 &    0.39 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   1 &    0.39 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   2 &    0.38 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   2 &    0.40 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 6 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   3 &    0.39 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.43 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   4 &    0.40 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.43 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   4 &    0.40 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   1 &    0.42 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 6 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   6 &    0.39 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.46 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   3 &    0.40 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   1 &    0.46 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   3 &    0.40 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.46 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 8 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   1 &    0.39 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   2 &    0.38 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   2 &    0.40 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   2 &    0.38 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   4 &    0.39 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   2 &    0.38 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 8 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   6 &    0.39 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   1 &    0.41 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   3 &    0.39 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.43 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   1 &    0.41 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   1 &    0.43 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 8 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   4 &    0.41 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.47 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   5 &    0.39 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.48 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   2 &    0.40 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.47 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 2 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   3 &    0.40 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   1 &    0.42 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   0 &    0.42 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   4 &    0.40 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   2 &    0.42 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   2 &    0.41 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 2 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   3 &    0.38 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.41 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   3 &    0.37 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.41 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   5 &    0.36 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.42 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 2 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   4 &    0.36 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.52 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   3 &    0.38 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.53 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   4 &    0.38 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.56 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 4 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   4 &    0.33 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   5 &    0.32 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   3 &    0.34 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.35 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   4 &    0.33 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.37 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 4 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   7 &    0.35 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.44 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   4 &    0.36 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.45 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   0 &    0.40 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.47 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 4 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   5 &    0.69 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.88 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   3 &    0.68 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.88 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   2 &    0.81 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.93 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 6 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   3 &    0.48 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   6 &    0.43 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   0 &    0.50 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.50 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   1 &    0.52 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.58 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 6 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   5 &    0.55 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    0.64 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   3 &    0.57 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   1 &    0.64 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   2 &    0.56 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   1 &    0.67 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 6 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   3 &    1.86 &  0.01
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    2.30 &  0.01
# 10 &    cpsat_config &  II_A &   0 &   0 &   4 &    1.98 &  0.01
# 10 &    cpsat_config &  II_B &   0 &   0 &   1 &    2.04 &  0.01
# 10 &    cpsat_config & III_A &   0 &   0 &   2 &    1.96 &  0.01
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    2.41 &  0.01
#
#
#
#
# nb_target_plates: 5 size_target_plates: 8 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   4 &    0.48 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   3 &    0.51 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   1 &    0.53 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   1 &    0.54 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   1 &    0.56 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   1 &    0.61 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 8 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   3 &    0.58 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   1 &    0.65 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   3 &    0.57 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.70 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   3 &    0.60 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.71 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 8 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   5 &    2.34 &  0.01
# 10 &    cpsat_config &   I_B &   0 &   0 &   0 &    2.67 &  0.01
# 10 &    cpsat_config &  II_A &   0 &   0 &   1 &    2.37 &  0.01
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    2.69 &  0.01
# 10 &    cpsat_config & III_A &   0 &   0 &   2 &    2.34 &  0.01
# 10 &    cpsat_config & III_B &   0 &   0 &   2 &    2.84 &  0.01
#
#
#
#
# nb_target_plates: 10 size_target_plates: 2 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   4 &    0.41 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   6 &    0.40 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   1 &    0.43 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.44 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   0 &    0.46 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.52 &  0.00
#
#
#
#
# nb_target_plates: 10 size_target_plates: 2 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   4 &    1.89 &  0.01
# 10 &    cpsat_config &   I_B &   0 &   0 &   2 &    1.71 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   0 &    2.23 &  0.01
# 10 &    cpsat_config &  II_B &   0 &   0 &   2 &    1.84 &  0.01
# 10 &    cpsat_config & III_A &   0 &   0 &   1 &    1.84 &  0.01
# 10 &    cpsat_config & III_B &   0 &   0 &   1 &    2.36 &  0.01
#
#
#
#
# nb_target_plates: 10 size_target_plates: 2 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   1 &   1 &   5 &   38.65 &  0.11
# 10 &    cpsat_config &   I_B &   1 &   1 &   0 &   46.98 &  0.13
# 10 &    cpsat_config &  II_A &   1 &   1 &   2 &   42.40 &  0.12
# 10 &    cpsat_config &  II_B &   0 &   0 &   2 &   38.61 &  0.11
# 10 &    cpsat_config & III_A &   0 &   0 &   1 &   27.84 &  0.08
# 10 &    cpsat_config & III_B &   1 &   1 &   0 &   40.54 &  0.11
#
#
#
#
# nb_target_plates: 10 size_target_plates: 4 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   8 &    0.59 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   3 &    0.61 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   0 &    0.67 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.71 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   0 &    0.85 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    0.93 &  0.00
#
#
#
#
# nb_target_plates: 10 size_target_plates: 4 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   1 &   12.94 &  0.04
# 10 &    cpsat_config &   I_B &   0 &   0 &   3 &   11.63 &  0.03
# 10 &    cpsat_config &  II_A &   0 &   0 &   3 &   12.79 &  0.04
# 10 &    cpsat_config &  II_B &   0 &   0 &   3 &   10.35 &  0.03
# 10 &    cpsat_config & III_A &   0 &   0 &   0 &   13.11 &  0.04
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &   11.80 &  0.03
#
#
#
#
# nb_target_plates: 10 size_target_plates: 4 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   4 &   4 &   3 &  122.85 &  0.34
# 10 &    cpsat_config &   I_B &   4 &   4 &   1 &  123.92 &  0.34
# 10 &    cpsat_config &  II_A &   4 &   4 &   2 &  124.77 &  0.35
# 10 &    cpsat_config &  II_B &   4 &   4 &   0 &  126.23 &  0.35
# 10 &    cpsat_config & III_A &   4 &   4 &   0 &  123.56 &  0.34
# 10 &    cpsat_config & III_B &   4 &   4 &   0 &  125.29 &  0.35
#
#
#
#
# nb_target_plates: 10 size_target_plates: 6 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   7 &    0.63 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   3 &    0.65 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   1 &    0.74 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.78 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   1 &    0.91 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    1.09 &  0.00
#
#
#
#
# nb_target_plates: 10 size_target_plates: 6 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   3 &   30.77 &  0.09
# 10 &    cpsat_config &   I_B &   0 &   0 &   1 &   28.27 &  0.08
# 10 &    cpsat_config &  II_A &   0 &   0 &   2 &   30.88 &  0.09
# 10 &    cpsat_config &  II_B &   0 &   0 &   3 &   29.66 &  0.08
# 10 &    cpsat_config & III_A &   0 &   0 &   1 &   31.35 &  0.09
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &   32.52 &  0.09
#
#
#
#
# nb_target_plates: 10 size_target_plates: 6 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &   I_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_B &  10 &  10 &   0 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 10 size_target_plates: 8 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   7 &    1.03 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   3 &    1.29 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   0 &    1.47 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    1.31 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   0 &    2.06 &  0.01
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    2.25 &  0.01
#
#
#
#
# nb_target_plates: 10 size_target_plates: 8 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   2 &   58.31 &  0.16
# 10 &    cpsat_config &   I_B &   0 &   0 &   2 &   56.64 &  0.16
# 10 &    cpsat_config &  II_A &   0 &   0 &   2 &   56.12 &  0.16
# 10 &    cpsat_config &  II_B &   0 &   0 &   2 &   55.92 &  0.16
# 10 &    cpsat_config & III_A &   0 &   0 &   2 &   55.67 &  0.15
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &   53.52 &  0.15
#
#
#
#
# nb_target_plates: 10 size_target_plates: 8 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &   I_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_B &  10 &  10 &   0 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 15 size_target_plates: 2 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   6 &    0.65 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   5 &    0.65 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   0 &    0.71 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   1 &    0.73 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   0 &    0.98 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    1.15 &  0.00
#
#
#
#
# nb_target_plates: 15 size_target_plates: 2 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   5 &   5 &   2 &  169.26 &  0.47
# 10 &    cpsat_config &   I_B &   5 &   5 &   1 &  173.16 &  0.48
# 10 &    cpsat_config &  II_A &   5 &   5 &   0 &  164.82 &  0.46
# 10 &    cpsat_config &  II_B &   5 &   5 &   1 &  163.26 &  0.45
# 10 &    cpsat_config & III_A &   5 &   5 &   1 &  167.38 &  0.46
# 10 &    cpsat_config & III_B &   5 &   5 &   0 &  171.01 &  0.48
#
#
#
#
# nb_target_plates: 15 size_target_plates: 2 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   9 &   9 &   0 &  293.35 &  0.81
# 10 &    cpsat_config &   I_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_A &   9 &   9 &   0 &  292.71 &  0.81
# 10 &    cpsat_config &  II_B &   9 &   9 &   0 &  295.88 &  0.82
# 10 &    cpsat_config & III_A &   9 &   9 &   1 &  291.81 &  0.81
# 10 &    cpsat_config & III_B &   9 &   9 &   0 &  296.31 &  0.82
#
#
#
#
# nb_target_plates: 15 size_target_plates: 4 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   4 &    0.56 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   7 &    0.54 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   0 &    0.68 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    0.68 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   0 &    1.05 &  0.00
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    1.26 &  0.00
#
#
#
#
# nb_target_plates: 15 size_target_plates: 4 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   8 &   8 &   0 &  266.08 &  0.74
# 10 &    cpsat_config &   I_B &   8 &   8 &   1 &  254.57 &  0.71
# 10 &    cpsat_config &  II_A &   8 &   8 &   1 &  247.23 &  0.69
# 10 &    cpsat_config &  II_B &   7 &   7 &   1 &  237.10 &  0.66
# 10 &    cpsat_config & III_A &   8 &   8 &   0 &  260.28 &  0.72
# 10 &    cpsat_config & III_B &   7 &   7 &   0 &  242.41 &  0.67
#
#
#
#
# nb_target_plates: 15 size_target_plates: 4 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   9 &   9 &   1 &  270.98 &  0.75
# 10 &    cpsat_config &   I_B &   9 &   9 &   0 &  271.08 &  0.75
# 10 &    cpsat_config &  II_A &   9 &   9 &   0 &  271.10 &  0.75
# 10 &    cpsat_config &  II_B &   9 &   9 &   0 &  271.18 &  0.75
# 10 &    cpsat_config & III_A &   9 &   9 &   0 &  271.37 &  0.75
# 10 &    cpsat_config & III_B &   9 &   9 &   0 &  271.15 &  0.75
#
#
#
#
# nb_target_plates: 15 size_target_plates: 6 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   2 &    1.64 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   7 &    1.50 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   0 &    2.07 &  0.01
# 10 &    cpsat_config &  II_B &   0 &   0 &   1 &    2.01 &  0.01
# 10 &    cpsat_config & III_A &   0 &   0 &   0 &    3.02 &  0.01
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    3.75 &  0.01
#
#
#
#
# nb_target_plates: 15 size_target_plates: 6 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   5 &   5 &   1 &  164.66 &  0.46
# 10 &    cpsat_config &   I_B &   5 &   5 &   1 &  157.18 &  0.44
# 10 &    cpsat_config &  II_A &   5 &   5 &   3 &  155.35 &  0.43
# 10 &    cpsat_config &  II_B &   5 &   5 &   0 &  163.49 &  0.45
# 10 &    cpsat_config & III_A &   5 &   5 &   0 &  156.50 &  0.43
# 10 &    cpsat_config & III_B &   6 &   6 &   0 &  184.15 &  0.51
#
#
#
#
# nb_target_plates: 15 size_target_plates: 6 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   9 &   9 &   0 &  270.69 &  0.75
# 10 &    cpsat_config &   I_B &   9 &   9 &   1 &  270.58 &  0.75
# 10 &    cpsat_config &  II_A &   9 &   9 &   0 &  271.18 &  0.75
# 10 &    cpsat_config &  II_B &   9 &   9 &   0 &  273.58 &  0.76
# 10 &    cpsat_config & III_A &   9 &   9 &   0 &  271.16 &  0.75
# 10 &    cpsat_config & III_B &   9 &   9 &   0 &  272.29 &  0.76
#
#
#
#
# nb_target_plates: 15 size_target_plates: 8 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   0 &   0 &   9 &    0.93 &  0.00
# 10 &    cpsat_config &   I_B &   0 &   0 &   1 &    1.00 &  0.00
# 10 &    cpsat_config &  II_A &   0 &   0 &   0 &    1.33 &  0.00
# 10 &    cpsat_config &  II_B &   0 &   0 &   0 &    1.33 &  0.00
# 10 &    cpsat_config & III_A &   0 &   0 &   0 &    2.27 &  0.01
# 10 &    cpsat_config & III_B &   0 &   0 &   0 &    2.94 &  0.01
#
#
#
#
# nb_target_plates: 15 size_target_plates: 8 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &   9 &   9 &   1 &  270.39 &  0.75
# 10 &    cpsat_config &   I_B &   9 &   9 &   0 &  270.54 &  0.75
# 10 &    cpsat_config &  II_A &   9 &   9 &   0 &  270.47 &  0.75
# 10 &    cpsat_config &  II_B &   9 &   9 &   0 &  270.53 &  0.75
# 10 &    cpsat_config & III_A &   9 &   9 &   0 &  270.90 &  0.75
# 10 &    cpsat_config & III_B &   9 &   9 &   0 &  270.71 &  0.75
#
#
#
#
# nb_target_plates: 15 size_target_plates: 8 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &    cpsat_config &   I_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &   I_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config &  II_B &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_A &  10 &  10 &   0 &  300.00 &  0.83
# 10 &    cpsat_config & III_B &  10 &  10 &   0 &  300.00 &  0.83

# %%
print_general_stats_enumerate(df_gurobi, models, nb_target_plates, size_target_plates, nb_source_plates)
# Out:
# nb_target_plates: 2 size_target_plates: 2 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   7 &    0.27 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.30 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   7 &    0.27 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &    0.30 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   5 &    0.27 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.30 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 2 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   5 &    0.33 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   2 &    0.35 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   3 &    0.33 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   1 &    0.35 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   4 &    0.33 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.36 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 2 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   4 &    0.30 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.39 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   8 &    0.28 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &    0.40 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   2 &    0.30 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.39 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 4 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   4 &    0.36 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   1 &    0.38 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   1 &    0.37 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   1 &    0.38 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   5 &    0.36 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.40 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 4 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   5 &    0.39 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.43 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   4 &    0.39 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   1 &    0.42 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   2 &    0.39 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.44 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 4 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   3 &    0.39 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.49 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   0 &    0.39 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &    0.48 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   8 &    0.37 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.47 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 6 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   4 &    0.38 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   2 &    0.41 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   4 &    0.39 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   1 &    0.41 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   7 &    0.39 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.41 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 6 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   8 &    0.38 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.44 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   3 &    0.39 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &    0.44 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   1 &    0.40 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   1 &    0.43 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 6 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   3 &    0.39 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.50 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   6 &    0.37 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &    0.48 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   2 &    0.40 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.48 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 8 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   4 &    0.37 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.40 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   3 &    0.39 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &    0.39 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   4 &    0.37 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.41 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 8 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   5 &    0.38 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   1 &    0.42 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   5 &    0.39 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &    0.44 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   1 &    0.40 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.44 &  0.00
#
#
#
#
# nb_target_plates: 2 size_target_plates: 8 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   2 &    0.42 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.47 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   7 &    0.39 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   1 &    0.47 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   2 &    0.40 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.51 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 2 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   3 &    0.39 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   1 &    0.43 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   7 &    0.37 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   1 &    0.43 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   1 &    0.41 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.46 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 2 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   7 &    0.40 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.51 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   3 &    0.41 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &    0.51 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   1 &    0.44 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.57 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 2 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   5 &    0.74 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &    0.97 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   5 &    0.73 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &    0.96 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   1 &    0.79 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    1.02 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 4 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   6 &    0.36 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   2 &    0.41 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   3 &    0.39 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   1 &    0.42 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   1 &    0.41 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    0.45 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 4 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   2 &    1.24 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   1 &    1.22 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   2 &    1.26 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &    1.46 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   5 &    1.06 &  0.00
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    1.43 &  0.00
#
#
#
#
# nb_target_plates: 5 size_target_plates: 4 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   3 &   49.94 &  0.14
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &   53.52 &  0.15
# 10 &   gurobi_config &  II_A &   0 &   0 &   0 &   49.25 &  0.14
# 10 &   gurobi_config &  II_B &   0 &   0 &   3 &   46.63 &  0.13
# 10 &   gurobi_config & III_A &   0 &   0 &   3 &   43.59 &  0.12
# 10 &   gurobi_config & III_B &   0 &   0 &   1 &   46.24 &  0.13
#
#
#
#
# nb_target_plates: 5 size_target_plates: 6 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   1 &   17.24 &  0.05
# 10 &   gurobi_config &   I_B &   0 &   0 &   3 &   15.52 &  0.04
# 10 &   gurobi_config &  II_A &   0 &   0 &   1 &   17.13 &  0.05
# 10 &   gurobi_config &  II_B &   0 &   0 &   2 &   14.58 &  0.04
# 10 &   gurobi_config & III_A &   0 &   0 &   3 &   14.12 &  0.04
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &   17.68 &  0.05
#
#
#
#
# nb_target_plates: 5 size_target_plates: 6 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   5 &    8.64 &  0.02
# 10 &   gurobi_config &   I_B &   0 &   0 &   3 &    6.68 &  0.02
# 10 &   gurobi_config &  II_A &   0 &   0 &   1 &   10.26 &  0.03
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &   10.68 &  0.03
# 10 &   gurobi_config & III_A &   0 &   0 &   1 &   10.22 &  0.03
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    9.79 &  0.03
#
#
#
#
# nb_target_plates: 5 size_target_plates: 6 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   1 &   0 &   2 &  135.97 &  0.38
# 10 &   gurobi_config &   I_B &   2 &   0 &   2 &  147.34 &  0.41
# 10 &   gurobi_config &  II_A &   2 &   0 &   3 &  151.69 &  0.42
# 10 &   gurobi_config &  II_B &   2 &   0 &   2 &  144.96 &  0.40
# 10 &   gurobi_config & III_A &   2 &   0 &   2 &  146.81 &  0.41
# 10 &   gurobi_config & III_B &   2 &   0 &   4 &  138.72 &  0.39
#
#
#
#
# nb_target_plates: 5 size_target_plates: 8 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   1 &   14.94 &  0.04
# 10 &   gurobi_config &   I_B &   0 &   0 &   2 &   15.88 &  0.04
# 10 &   gurobi_config &  II_A &   0 &   0 &   1 &   16.74 &  0.05
# 10 &   gurobi_config &  II_B &   0 &   0 &   2 &   12.87 &  0.04
# 10 &   gurobi_config & III_A &   0 &   0 &   4 &   11.18 &  0.03
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &   15.92 &  0.04
#
#
#
#
# nb_target_plates: 5 size_target_plates: 8 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   2 &   21.33 &  0.06
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &   20.30 &  0.06
# 10 &   gurobi_config &  II_A &   0 &   0 &   1 &   19.67 &  0.05
# 10 &   gurobi_config &  II_B &   0 &   0 &   5 &   19.40 &  0.05
# 10 &   gurobi_config & III_A &   0 &   0 &   1 &   20.80 &  0.06
# 10 &   gurobi_config & III_B &   0 &   0 &   1 &   21.74 &  0.06
#
#
#
#
# nb_target_plates: 5 size_target_plates: 8 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   7 &   0 &   5 &  240.50 &  0.67
# 10 &   gurobi_config &   I_B &   6 &   0 &   5 &  240.95 &  0.67
# 10 &   gurobi_config &  II_A &   5 &   0 &   6 &  226.02 &  0.63
# 10 &   gurobi_config &  II_B &   5 &   0 &   5 &  232.51 &  0.65
# 10 &   gurobi_config & III_A &   7 &   0 &   5 &  236.75 &  0.66
# 10 &   gurobi_config & III_B &   7 &   0 &   4 &  244.78 &  0.68
#
#
#
#
# nb_target_plates: 10 size_target_plates: 2 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   2 &   15.00 &  0.04
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &   15.50 &  0.04
# 10 &   gurobi_config &  II_A &   0 &   0 &   1 &   16.54 &  0.05
# 10 &   gurobi_config &  II_B &   0 &   0 &   1 &   15.92 &  0.04
# 10 &   gurobi_config & III_A &   0 &   0 &   1 &   17.12 &  0.05
# 10 &   gurobi_config & III_B &   0 &   0 &   5 &   14.25 &  0.04
#
#
#
#
# nb_target_plates: 10 size_target_plates: 2 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   7 &   0 &   7 &  253.62 &  0.70
# 10 &   gurobi_config &   I_B &   7 &   0 &   7 &  249.10 &  0.69
# 10 &   gurobi_config &  II_A &   7 &   0 &   9 &  237.93 &  0.66
# 10 &   gurobi_config &  II_B &   7 &   0 &   7 &  242.56 &  0.67
# 10 &   gurobi_config & III_A &   7 &   0 &   8 &  243.74 &  0.68
# 10 &   gurobi_config & III_B &   7 &   0 &   7 &  242.82 &  0.67
#
#
#
#
# nb_target_plates: 10 size_target_plates: 2 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   8 &   0 &   7 &  267.88 &  0.74
# 10 &   gurobi_config &   I_B &   8 &   0 &   8 &  266.87 &  0.74
# 10 &   gurobi_config &  II_A &   8 &   0 &   7 &  270.80 &  0.75
# 10 &   gurobi_config &  II_B &   8 &   0 &   8 &  257.39 &  0.71
# 10 &   gurobi_config & III_A &   7 &   0 &   8 &  255.74 &  0.71
# 10 &   gurobi_config & III_B &   7 &   0 &   7 &  256.34 &  0.71
#
#
#
#
# nb_target_plates: 10 size_target_plates: 4 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   2 &   16.38 &  0.05
# 10 &   gurobi_config &   I_B &   0 &   0 &   0 &   19.26 &  0.05
# 10 &   gurobi_config &  II_A &   0 &   0 &   5 &   12.35 &  0.03
# 10 &   gurobi_config &  II_B &   0 &   0 &   3 &   16.00 &  0.04
# 10 &   gurobi_config & III_A &   0 &   0 &   0 &   20.16 &  0.06
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &   19.12 &  0.05
#
#
#
#
# nb_target_plates: 10 size_target_plates: 4 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   9 &   0 &  10 &  276.71 &  0.77
# 10 &   gurobi_config &   I_B &   9 &   0 &   9 &  279.09 &  0.78
# 10 &   gurobi_config &  II_A &   9 &   0 &   9 &  278.14 &  0.77
# 10 &   gurobi_config &  II_B &   9 &   0 &   9 &  278.88 &  0.77
# 10 &   gurobi_config & III_A &   9 &   0 &   9 &  279.60 &  0.78
# 10 &   gurobi_config & III_B &   9 &   0 &   9 &  280.64 &  0.78
#
#
#
#
# nb_target_plates: 10 size_target_plates: 4 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &  10 &   0 &   2 &  300.00 &  0.83
# 10 &   gurobi_config &   I_B &  10 &   0 &   5 &  300.00 &  0.83
# 10 &   gurobi_config &  II_A &  10 &   0 &   8 &  300.00 &  0.83
# 10 &   gurobi_config &  II_B &  10 &   0 &   7 &  300.00 &  0.83
# 10 &   gurobi_config & III_A &  10 &   0 &   7 &  300.00 &  0.83
# 10 &   gurobi_config & III_B &  10 &   0 &   6 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 10 size_target_plates: 6 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   1 &   18.54 &  0.05
# 10 &   gurobi_config &   I_B &   0 &   0 &   3 &   17.03 &  0.05
# 10 &   gurobi_config &  II_A &   0 &   0 &   3 &   16.45 &  0.05
# 10 &   gurobi_config &  II_B &   0 &   0 &   1 &   16.98 &  0.05
# 10 &   gurobi_config & III_A &   0 &   0 &   1 &   18.57 &  0.05
# 10 &   gurobi_config & III_B &   0 &   0 &   1 &   19.69 &  0.05
#
#
#
#
# nb_target_plates: 10 size_target_plates: 6 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   9 &   0 &   9 &  284.18 &  0.79
# 10 &   gurobi_config &   I_B &   9 &   0 &   9 &  281.02 &  0.78
# 10 &   gurobi_config &  II_A &   9 &   0 &   9 &  279.94 &  0.78
# 10 &   gurobi_config &  II_B &   9 &   0 &   9 &  280.27 &  0.78
# 10 &   gurobi_config & III_A &   9 &   0 &   9 &  283.85 &  0.79
# 10 &   gurobi_config & III_B &   9 &   0 &  10 &  278.01 &  0.77
#
#
#
#
# nb_target_plates: 10 size_target_plates: 6 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &  10 &   0 &   4 &  300.00 &  0.83
# 10 &   gurobi_config &   I_B &  10 &   0 &   5 &  300.00 &  0.83
# 10 &   gurobi_config &  II_A &  10 &   0 &   3 &  300.00 &  0.83
# 10 &   gurobi_config &  II_B &  10 &   0 &   3 &  300.00 &  0.83
# 10 &   gurobi_config & III_A &  10 &   0 &   6 &  300.00 &  0.83
# 10 &   gurobi_config & III_B &  10 &   0 &   3 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 10 size_target_plates: 8 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   2 &   14.97 &  0.04
# 10 &   gurobi_config &   I_B &   0 &   0 &   2 &   14.16 &  0.04
# 10 &   gurobi_config &  II_A &   0 &   0 &   2 &   15.83 &  0.04
# 10 &   gurobi_config &  II_B &   0 &   0 &   2 &   18.23 &  0.05
# 10 &   gurobi_config & III_A &   0 &   0 &   2 &   15.41 &  0.04
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &   18.06 &  0.05
#
#
#
#
# nb_target_plates: 10 size_target_plates: 8 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config &   I_B &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config &  II_A &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config &  II_B &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config & III_A &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config & III_B &  10 &   0 &  10 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 10 size_target_plates: 8 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &  10 &   0 &   4 &  300.00 &  0.83
# 10 &   gurobi_config &   I_B &  10 &   0 &   3 &  300.00 &  0.83
# 10 &   gurobi_config &  II_A &  10 &   0 &   2 &  300.00 &  0.83
# 10 &   gurobi_config &  II_B &  10 &   0 &   5 &  300.00 &  0.83
# 10 &   gurobi_config & III_A &  10 &   0 &   3 &  300.00 &  0.83
# 10 &   gurobi_config & III_B &  10 &   0 &   3 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 15 size_target_plates: 2 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   2 &   16.86 &  0.05
# 10 &   gurobi_config &   I_B &   0 &   0 &   1 &   17.74 &  0.05
# 10 &   gurobi_config &  II_A &   0 &   0 &   2 &   17.59 &  0.05
# 10 &   gurobi_config &  II_B &   0 &   0 &   2 &   16.48 &  0.05
# 10 &   gurobi_config & III_A &   0 &   0 &   1 &   16.35 &  0.05
# 10 &   gurobi_config & III_B &   0 &   0 &   2 &   14.73 &  0.04
#
#
#
#
# nb_target_plates: 15 size_target_plates: 2 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config &   I_B &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config &  II_A &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config &  II_B &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config & III_A &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config & III_B &  10 &   0 &  10 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 15 size_target_plates: 2 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   9 &   0 &   9 &  281.19 &  0.78
# 10 &   gurobi_config &   I_B &   9 &   0 &   8 &  279.12 &  0.78
# 10 &   gurobi_config &  II_A &   9 &   0 &   9 &  279.63 &  0.78
# 10 &   gurobi_config &  II_B &   9 &   0 &   9 &  280.58 &  0.78
# 10 &   gurobi_config & III_A &   9 &   0 &   8 &  279.17 &  0.78
# 10 &   gurobi_config & III_B &   9 &   0 &   9 &  280.79 &  0.78
#
#
#
#
# nb_target_plates: 15 size_target_plates: 4 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   2 &   13.36 &  0.04
# 10 &   gurobi_config &   I_B &   0 &   0 &   2 &   15.85 &  0.04
# 10 &   gurobi_config &  II_A &   0 &   0 &   1 &   15.92 &  0.04
# 10 &   gurobi_config &  II_B &   0 &   0 &   3 &   15.62 &  0.04
# 10 &   gurobi_config & III_A &   0 &   0 &   0 &   19.66 &  0.05
# 10 &   gurobi_config & III_B &   0 &   0 &   2 &   17.26 &  0.05
#
#
#
#
# nb_target_plates: 15 size_target_plates: 4 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config &   I_B &  10 &   0 &   9 &  300.00 &  0.83
# 10 &   gurobi_config &  II_A &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config &  II_B &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config & III_A &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config & III_B &  10 &   0 &  10 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 15 size_target_plates: 4 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &  10 &   0 &   2 &  300.00 &  0.83
# 10 &   gurobi_config &   I_B &  10 &   0 &   4 &  300.00 &  0.83
# 10 &   gurobi_config &  II_A &  10 &   0 &   1 &  300.00 &  0.83
# 10 &   gurobi_config &  II_B &  10 &   0 &   5 &  300.00 &  0.83
# 10 &   gurobi_config & III_A &  10 &   0 &   3 &  300.00 &  0.83
# 10 &   gurobi_config & III_B &  10 &   0 &   4 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 15 size_target_plates: 6 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   3 &   16.73 &  0.05
# 10 &   gurobi_config &   I_B &   0 &   0 &   1 &   16.90 &  0.05
# 10 &   gurobi_config &  II_A &   0 &   0 &   4 &   14.08 &  0.04
# 10 &   gurobi_config &  II_B &   0 &   0 &   1 &   14.47 &  0.04
# 10 &   gurobi_config & III_A &   0 &   0 &   0 &   21.95 &  0.06
# 10 &   gurobi_config & III_B &   0 &   0 &   1 &   23.59 &  0.07
#
#
#
#
# nb_target_plates: 15 size_target_plates: 6 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config &   I_B &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config &  II_A &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config &  II_B &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config & III_A &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config & III_B &  10 &   0 &   8 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 15 size_target_plates: 6 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &  10 &   0 &   2 &  300.00 &  0.83
# 10 &   gurobi_config &   I_B &  10 &   0 &   5 &  300.00 &  0.83
# 10 &   gurobi_config &  II_A &  10 &   0 &   5 &  300.00 &  0.83
# 10 &   gurobi_config &  II_B &  10 &   0 &   4 &  300.00 &  0.83
# 10 &   gurobi_config & III_A &  10 &   0 &   5 &  300.00 &  0.83
# 10 &   gurobi_config & III_B &  10 &   0 &   6 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 15 size_target_plates: 8 nb_source_plates: 2 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &   0 &   0 &   9 &    0.96 &  0.00
# 10 &   gurobi_config &   I_B &   0 &   0 &   1 &    1.19 &  0.00
# 10 &   gurobi_config &  II_A &   0 &   0 &   0 &    1.37 &  0.00
# 10 &   gurobi_config &  II_B &   0 &   0 &   0 &    1.37 &  0.00
# 10 &   gurobi_config & III_A &   0 &   0 &   0 &    2.57 &  0.01
# 10 &   gurobi_config & III_B &   0 &   0 &   0 &    3.07 &  0.01
#
#
#
#
# nb_target_plates: 15 size_target_plates: 8 nb_source_plates: 5 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config &   I_B &  10 &   0 &   9 &  300.00 &  0.83
# 10 &   gurobi_config &  II_A &  10 &   0 &   9 &  300.00 &  0.83
# 10 &   gurobi_config &  II_B &  10 &   0 &  10 &  300.00 &  0.83
# 10 &   gurobi_config & III_A &  10 &   0 &   9 &  300.00 &  0.83
# 10 &   gurobi_config & III_B &  10 &   0 &   9 &  300.00 &  0.83
#
#
#
#
# nb_target_plates: 15 size_target_plates: 8 nb_source_plates: 10 nb_problems: 10
# NbP &     solver_name & model & T/O & N/S & Nbt &  avg. t & total
# 10 &   gurobi_config &   I_A &  10 &   0 &   5 &  300.00 &  0.83
# 10 &   gurobi_config &   I_B &  10 &   0 &   4 &  300.00 &  0.83
# 10 &   gurobi_config &  II_A &  10 &   0 &   5 &  300.00 &  0.83
# 10 &   gurobi_config &  II_B &  10 &   0 &   4 &  300.00 &  0.83
# 10 &   gurobi_config & III_A &  10 &   0 &   6 &  300.00 &  0.83
# 10 &   gurobi_config & III_B &  10 &   0 &   5 &  300.00 &  0.83
